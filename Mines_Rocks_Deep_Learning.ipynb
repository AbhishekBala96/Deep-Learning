# %%
#importing libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
#loading data
df = pd.read_csv("sonar_data.csv", header=None)
df.head()
# Out:
#        0       1       2       3       4   ...      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032   R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044   R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078   R
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117   R
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
#checking dimensions
df.shape
# Out:
# (208, 61)

# %%
df.groupby(60).size()
# Out:
# 60
# M    111
# R     97
# dtype: int64

# %%
#correlation matrix
sns.heatmap(df.corr())
plt.show()

# %%
x = df.values[:,0:-1].astype(float)
y = df.values[:,-1]

x_scale = StandardScaler().fit_transform(x)

# %%
y_encode
# Out:
#      M  R
# 0    0  1
# 1    0  1
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 203  1  0
# 204  1  0
# 205  1  0
# 206  1  0
# 207  1  0
#
# [208 rows x 2 columns]

# %%
import keras
from keras.layers import Dense
from keras.models import Sequential
from keras.utils import to_categorical

y_encode = to_categorical(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-8d28158db748> in <module>()
#       4 from keras.utils import to_categorical
#       5
# ----> 6 y_encode = to_categorical(y)
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/np_utils.py in to_categorical(y, num_classes, dtype)
#      41     """
#      42
# ---> 43     y = np.array(y, dtype='int')
#      44     input_shape = y.shape
#      45     if input_shape and input_shape[-1] == 1 and len(input_shape) > 1:
#
# ValueError: invalid literal for int() with base 10: 'R'

# %%
#initialize model
model = Sequential()
model.add(Dense(2, input_shape=(60,), activation='sigmoid'))
model.compile(optimizer= 'adam', loss= 'binary_crossentropy', metrics=['accuracy'])

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scale, y_encode, train_size=0.8, random_state=101)

# %%
model.fit(x_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 166/166 [==============================] - 0s 478us/step - loss: 0.7302 - accuracy: 0.5753
# Epoch 2/50
# 166/166 [==============================] - 0s 77us/step - loss: 0.7075 - accuracy: 0.5813
# Epoch 3/50
# 166/166 [==============================] - 0s 71us/step - loss: 0.6879 - accuracy: 0.5934
# Epoch 4/50
# 166/166 [==============================] - 0s 65us/step - loss: 0.6696 - accuracy: 0.6024
# Epoch 5/50
# 166/166 [==============================] - 0s 70us/step - loss: 0.6543 - accuracy: 0.6175
# Epoch 6/50
# 166/166 [==============================] - 0s 77us/step - loss: 0.6404 - accuracy: 0.6295
# Epoch 7/50
# 166/166 [==============================] - 0s 68us/step - loss: 0.6282 - accuracy: 0.6476
# Epoch 8/50
# 166/166 [==============================] - 0s 62us/step - loss: 0.6169 - accuracy: 0.6627
# Epoch 9/50
# 166/166 [==============================] - 0s 60us/step - loss: 0.6068 - accuracy: 0.6747
# Epoch 10/50
# ...

# %%
plt.rcParams
y_preds = model2.predict_classes(x_test).reshape(-1,).astype(np.int8)


plt.subplot(121)
plt.scatter(x_test[:,0], x_test[:,2], color = [['red', 'blue'][x] for x in y_preds])
plt.title('Predictions')
plt.subplot(122)
plt.scatter(x_test[:,0], x_test[:,2], color = [['red', 'blue'][x] for x in y_test])
plt.title('Truth')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-aa7373be6a90> in <module>()
#       7 plt.title('Predictions')
#       8 plt.subplot(122)
# ----> 9 plt.scatter(x_test[:,0], x_test[:,2], color = [['red', 'blue'][x] for x in y_test])
#      10 plt.title('Truth')
#      11 plt.show()
#
# <ipython-input-81-aa7373be6a90> in <listcomp>(.0)
#       7 plt.title('Predictions')
#       8 plt.subplot(122)
# ----> 9 plt.scatter(x_test[:,0], x_test[:,2], color = [['red', 'blue'][x] for x in y_test])
#      10 plt.title('Truth')
#      11 plt.show()
#
# TypeError: list indices must be integers or slices, not str

# %%
from keras import optimizers

model2 = Sequential()
model2.add(Dense(8, input_shape=(60,), activation='sigmoid'))
model2.add(Dense(8, activation='sigmoid'))
model2.add(Dense(3, activation='sigmoid'))
model2.add(Dense(2, activation='sigmoid'))

SGD = optimizers.SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model2.compile(optimizer=SGD, loss='binary_crossentropy', metrics=['accuracy'])

# %%
model2.fit(x_train, y_train, epochs=100, verbose=2)
# Out:
# Epoch 1/100
#  - 0s - loss: 0.7351 - accuracy: 0.4578
# Epoch 2/100
#  - 0s - loss: 0.7006 - accuracy: 0.4699
# Epoch 3/100
#  - 0s - loss: 0.6939 - accuracy: 0.5422
# Epoch 4/100
#  - 0s - loss: 0.6906 - accuracy: 0.5422
# Epoch 5/100
#  - 0s - loss: 0.6900 - accuracy: 0.5422
# Epoch 6/100
#  - 0s - loss: 0.6913 - accuracy: 0.5422
# Epoch 7/100
#  - 0s - loss: 0.6908 - accuracy: 0.5422
# Epoch 8/100
#  - 0s - loss: 0.6900 - accuracy: 0.5422
# Epoch 9/100
#  - 0s - loss: 0.6916 - accuracy: 0.5422
# Epoch 10/100
#  - 0s - loss: 0.6910 - accuracy: 0.5422
# Epoch 11/100
#  - 0s - loss: 0.6894 - accuracy: 0.5422
# Epoch 12/100
#  - 0s - loss: 0.6917 - accuracy: 0.5422
# Epoch 13/100
#  - 0s - loss: 0.6900 - accuracy: 0.5422
# Epoch 14/100
#  - 0s - loss: 0.6902 - accuracy: 0.5422
# Epoch 15/100
#  - 0s - loss: 0.6909 - accuracy: 0.5422
# Epoch 16/100
#  - 0s - loss: 0.6913 - accuracy: 0.5422
# Epoch 17/100
#  - 0s - loss: 0.6895 - accuracy: 0.5422
# Epoch 18/100
# ...

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-bf5c8bfa512c> in <module>()
#       1 from sklearn.metrics import accuracy_score
# ----> 2 print(accuracy_score(y_test, y_pred))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     183
#     184     # Compute accuracy for each possible representation
# --> 185     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     186     check_consistent_length(y_true, y_pred, sample_weight)
#     187     if y_type.startswith('multilabel'):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      88     if len(y_type) > 1:
#      89         raise ValueError("Classification metrics can't handle a mix of {0} "
# ...
